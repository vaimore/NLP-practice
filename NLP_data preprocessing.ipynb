# %%
import pandas as pd
import numpy as np
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
import matplotlib.pyplot as plt

df = pd.read_csv('E:/Vaibhav/Study_CS/365DataScience/tripadvisor_hotel_reviews.csv')
df
# Out:
#                                                 Review  Rating
# 0    nice hotel expensive parking got good deal sta...       4
# 1    ok nothing special charge diamond member hilto...       2
# 2    nice rooms not 4* experience hotel monaco seat...       3
# 3    unique, great stay, wonderful time hotel monac...       5
# 4    great stay great stay, went seahawk game aweso...       5
# ..                                                 ...     ...
# 104  fairmont hotel singapore splendid, stayed fair...       5
# 105  great hotel stayed hotel night route perth chr...       4
# 106  great hotel centre stayed 5 nights room overlo...       4
# 107  great location great value great hotel husband...       5
# 108  lovely hotel great location stayed vacation to...       5
#
# [109 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  109 non-null    object
#  1   Rating  109 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 1.8+ KB

# %%
df['Review'][0]
# Out:
# 'nice hotel expensive parking got good deal stay hotel anniversary, arrived late evening took advice previous reviews did valet parking, check quick easy, little disappointed non-existent view room room clean nice size, bed comfortable woke stiff neck high pillows, not soundproof like heard music room night morning loud bangs doors opening closing hear people talking hallway, maybe just noisy neighbors, aveda bath products nice, did not goldfish stay nice touch taken advantage staying longer, location great walking distance shopping, overall nice experience having pay 40 parking night,  '

# %%
df['Review_lowercase'] = df['Review'].str.lower()

# %%
df.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     Review_lowercase
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...

# %%
en_stopwords = stopwords.words('english')

# %%
en_stopwords.remove('not')

# %%
df['review_no_stopword'] = df['Review_lowercase'].apply( lambda x: ' '.join([word for word in x.split() if word not in (en_stopwords)]))

# %%
df.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     Review_lowercase  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...
#
#                                   review_no_stopword
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# ...

# %%
df['review_no_stopword'][0]
# Out:
# 'nice hotel expensive parking got good deal stay hotel anniversary, arrived late evening took advice previous reviews valet parking, check quick easy, little disappointed non-existent view room room clean nice size, bed comfortable woke stiff neck high pillows, not soundproof like heard music room night morning loud bangs doors opening closing hear people talking hallway, maybe noisy neighbors, aveda bath products nice, not goldfish stay nice touch taken advantage staying longer, location great walking distance shopping, overall nice experience pay 40 parking night,'

# %%
df['review_no_stopword_no_punct'] = df.apply(lambda x: re.sub(r"[*]", "star", x['review_no_stopword']),axis=1)

# %%
df.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     Review_lowercase  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...
#
#                                   review_no_stopword  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# ...

# %%
df['review_no_stopword_no_punct'] = df.apply(lambda x: re.sub(r"([^\w\s])", "", x['review_no_stopword_no_punct']),axis=1)

# %%
df.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     Review_lowercase  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...
#
#                                   review_no_stopword  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# ...

# %%
df['tokenized'] = df.apply(lambda x: word_tokenize(x['review_no_stopword_no_punct']),axis=1)

# %%
df.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     Review_lowercase  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...
#
#                                   review_no_stopword  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# ...

# %%
df['tokenized'][0]
# Out:
# ['nice',
#  'hotel',
#  'expensive',
#  'parking',
#  'got',
#  'good',
#  'deal',
#  'stay',
#  'hotel',
#  'anniversary',
#  'arrived',
#  'late',
#  'evening',
#  'took',
#  'advice',
#  'previous',
#  'reviews',
#  'valet',
#  'parking',
#  'check',
#  'quick',
#  'easy',
#  'little',
#  'disappointed',
#  'nonexistent',
#  'view',
#  'room',
#  'room',
#  'clean',
#  'nice',
#  'size',
#  'bed',
#  'comfortable',
#  'woke',
#  'stiff',
#  'neck',
#  'high',
#  'pillows',
#  'not',
#  'soundproof',
#  'like',
#  'heard',
#  'music',
#  'room',
#  'night',
#  'morning',
#  'loud',
#  'bangs',
#  'doors',
#  'opening',
#  'closing',
#  'hear',
#  'people',
#  'talking',
#  'hallway',
#  'maybe',
#  'noisy',
#  'neighbors',
#  'aveda',
#  'bath',
#  'products',
#  'nice',
#  'not',
#  'goldfish',
#  'stay',
#  'nice',
#  'touch',
#  'taken',
#  'advantage',
#  'staying',
#  'longer',
#  'location',
#  'great',
#  'walking',
#  'distance',
#  'shopping',
#  'overall',
#  'nice',
# ...

# %%
ps = PorterStemmer()

# %%
df['stemmed'] = df['tokenized'].apply(lambda tokens: [ps.stem(token) for token in tokens])

# %%
df.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     Review_lowercase  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...
#
#                                   review_no_stopword  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# ...

# %%
lemmatizer = WordNetLemmatizer()

# %%
df['lemmatizer'] = df['tokenized'].apply(lambda tokens: [lemmatizer.lemmatize(token) for token in tokens])

# %%
df.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     Review_lowercase  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...
#
#                                   review_no_stopword  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# ...

# %%
tokens_clean = sum(df['lemmatizer'], [])

# %%
tokens_clean
# Out:
# ['nice',
#  'hotel',
#  'expensive',
#  'parking',
#  'got',
#  'good',
#  'deal',
#  'stay',
#  'hotel',
#  'anniversary',
#  'arrived',
#  'late',
#  'evening',
#  'took',
#  'advice',
#  'previous',
#  'review',
#  'valet',
#  'parking',
#  'check',
#  'quick',
#  'easy',
#  'little',
#  'disappointed',
#  'nonexistent',
#  'view',
#  'room',
#  'room',
#  'clean',
#  'nice',
#  'size',
#  'bed',
#  'comfortable',
#  'woke',
#  'stiff',
#  'neck',
#  'high',
#  'pillow',
#  'not',
#  'soundproof',
#  'like',
#  'heard',
#  'music',
#  'room',
#  'night',
#  'morning',
#  'loud',
#  'bang',
#  'door',
#  'opening',
#  'closing',
#  'hear',
#  'people',
#  'talking',
#  'hallway',
#  'maybe',
#  'noisy',
#  'neighbor',
#  'aveda',
#  'bath',
#  'product',
#  'nice',
#  'not',
#  'goldfish',
#  'stay',
#  'nice',
#  'touch',
#  'taken',
#  'advantage',
#  'staying',
#  'longer',
#  'location',
#  'great',
#  'walking',
#  'distance',
#  'shopping',
#  'overall',
#  'nice',
# ...

# %%
unigram = (pd.Series(nltk.ngrams(tokens_clean, 1)).value_counts())
print(unigram)
# Out:
# (hotel,)           292
# (room,)            275
# (great,)           126
# (not,)             122
# (stay,)             95
#                   ...
# (la,)                1
# (175,)               1
# (smackagainst,)      1
# (2x,)                1
# (connected,)         1
# Length: 2588, dtype: int64

# %%
bigram = (pd.Series(nltk.ngrams(tokens_clean, 2)).value_counts())
print(bigram)
# Out:
# (great, location)     24
# (space, needle)       21
# (hotel, monaco)       16
# (great, hotel)        12
# (staff, friendly)     12
#                       ..
# (didnt, make)          1
# (personnel, didnt)     1
# (minute, stay)         1
# (starting, minute)     1
# (food, raffle)         1
# Length: 8263, dtype: int64

# %%
trigram = (pd.Series(nltk.ngrams(tokens_clean, 3)).value_counts())
print(trigram)
# Out:
# (pike, place, market)            8
# (view, space, needle)            5
# (hotel, great, location)         5
# (inn, queen, anne)               4
# (room, king, bed)                4
#                                 ..
# (hotel, dissapointment, trip)    1
# (dissapointment, trip, 3)        1
# (trip, 3, night)                 1
# (3, night, stay)                 1
# (hotel, right, street)           1
# Length: 9288, dtype: int64

# %%
unigram[:20].sort_values().plot.barh(color = 'lightsalmon', width = .9, figsize=(10,5))
plt.title("20 most frequently occuring unigrams")
# Out:
# Text(0.5, 1.0, '20 most frequently occuring unigrams')

# %%
bigram[:10].sort_values().plot.barh(color = 'lightsalmon', width = .9, figsize=(10,5))
plt.title("10 most frequently occuring unigrams")
# Out:
# Text(0.5, 1.0, '10 most frequently occuring unigrams')

# %%
trigram[:10].sort_values().plot.barh(color = 'lightsalmon', width = .9, figsize=(10,5))
plt.title("10 most frequently occuring unigrams")
# Out:
# Text(0.5, 1.0, '10 most frequently occuring unigrams')
